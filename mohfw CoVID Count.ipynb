# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import date

# %%
url='https://www.mohfw.gov.in/'

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, "lxml")
# print(soup.prettify()

# %%
my_table = soup.find_all('table', {'class':'table table-striped table-dark'})
my_table = my_table[-1].get_text()
data = my_table.split('\n')
data.remove('')

# %%
head = ['Date']
dates = []
state = []
conf_ind = []
conf_for = []
discharged = []
dead = []
print('===============================Header================================')
for i in range(3, 8):
#     print(data[i])
    head.append(data[i])

# Preparing list for each column    
print('===============================States================================')
for i in range(13, len(data), 8):
#     print(data[i])
    state.append(data[i])
state = state[: len(state) - 2] 

print('================================Date==================================')
for i in range(len(state)):
#     print(date.today())
    dates.append(date.today())


print('===========================Confirmed Indian==========================')
for i in range(14, len(data), 8):
#     print(data[i])
    conf_ind.append(data[i])
conf_ind = conf_ind[: len(conf_ind) - 2]

print('==========================Confirmed Foreign==========================')    
for i in range(15, len(data), 8):
#     print(data[i])
    conf_for.append(data[i])
conf_for = conf_for[: len(conf_for) - 2]
    
print('========================Discharged or Migrated=======================')    
for i in range(16, len(data), 8):
#     print(data[i])
    discharged.append(data[i])
discharged = discharged[: len(discharged) - 2]
    
print('================================Death================================')
for i in range(17, len(data), 8):
#     print(data[i])
    dead.append(data[i])
dead = dead[: len(dead) - 2]
# Out:
# ===============================Header================================
# ===============================States================================
# ================================Date==================================
# ===========================Confirmed Indian==========================
# ==========================Confirmed Foreign==========================
# ========================Discharged or Migrated=======================
# ================================Death================================

# %%
state.append('Total number of confirmed cases in India')
dates.append(date.today())
# Sum of each column
for i in range(0, len(conf_ind)): 
    conf_ind[i] = int(conf_ind[i]) 
total = sum(conf_ind)
conf_ind.append(total)

for i in range(0, len(conf_for)): 
    conf_for[i] = int(conf_for[i]) 
total = sum(conf_for)
conf_for.append(total)

for i in range(0, len(discharged)): 
    discharged[i] = int(discharged[i]) 
total = sum(discharged)
discharged.append(total)

for i in range(0, len(dead)): 
    dead[i] = int(dead[i]) 
total = sum(dead)
dead.append(total)

# %%
dict = {head[0]: dates,
        head[1]: state, 
        head[2]: conf_ind,
        head[3]: conf_for,
        head[4]: discharged,
        head[5]: dead
        } 
CoVID_df = pd.DataFrame(dict)
CoVID_df
# Out:
#           Date                        Name of State / UT  \
# 0   2020-03-26                            Andhra Pradesh
# 1   2020-03-26                                     Bihar
# 2   2020-03-26                              Chhattisgarh
# 3   2020-03-26                                     Delhi
# 4   2020-03-26                                       Goa
# 5   2020-03-26                                   Gujarat
# 6   2020-03-26                                   Haryana
# 7   2020-03-26                          Himachal Pradesh
# 8   2020-03-26                                 Karnataka
# 9   2020-03-26                                    Kerala
# 10  2020-03-26                            Madhya Pradesh
# 11  2020-03-26                               Maharashtra
# 12  2020-03-26                                   Manipur
# 13  2020-03-26                                   Mizoram
# 14  2020-03-26                                    Odisha
# 15  2020-03-26                                Puducherry
# 16  2020-03-26                                    Punjab
# 17  2020-03-26                                 Rajasthan
# 18  2020-03-26                                Tamil Nadu
# 19  2020-03-26                                 Telengana
# 20  2020-03-26                                Chandigarh
# 21  2020-03-26                         Jammu and Kashmir
# 22  2020-03-26                                    Ladakh
# 23  2020-03-26                             Uttar Pradesh
# 24  2020-03-26                               Uttarakhand
# 25  2020-03-26                               West Bengal
# 26  2020-03-26  Total number of confirmed cases in India
#
#     Total Confirmed cases (Indian National)  \
# 0                                        11
# 1                                         3
# 2                                         3
# 3                                        34
# 4                                         3
# 5                                        37
# 6                                        16
# 7                                         3
# 8                                        41
# 9                                       110
# 10                                       15
# 11                                      121
# 12                                        1
# 13                                        1
# 14                                        2
# 15                                        1
# 16                                       33
# 17                                       36
# 18                                       20
# 19                                       31
# 20                                        7
# 21                                       11
# 22                                       13
# 23                                       36
# 24                                        4
# 25                                        9
# 26                                      602
#
#     Total Confirmed cases ( Foreign National )  Cured/Discharged/Migrated  \
# 0                                            0                          1
# 1                                            0                          0
# 2                                            0                          0
# 3                                            1                          6
# 4                                            0                          0
# 5                                            1                          0
# 6                                           14                         11
# 7                                            0                          0
# 8                                            0                          3
# 9                                            8                          4
# 10                                           0                          0
# 11                                           3                          1
# 12                                           0                          0
# 13                                           0                          0
# 14                                           0                          0
# 15                                           0                          0
# 16                                           0                          0
# 17                                           2                          3
# 18                                           6                          1
# 19                                          10                          1
# 20                                           0                          0
# 21                                           0                          1
# 22                                           0                          0
# 23                                           1                         11
# 24                                           1                          0
# 25                                           0                          0
# 26                                          47                         43
#
#     Death
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
# 5       2
# 6       0
# 7       1
# 8       1
# 9       0
# 10      1
# 11      3
# 12      0
# 13      0
# 14      0
# 15      0
# 16      1
# 17      0
# 18      1
# 19      0
# 20      0
# 21      0
# 22      0
# 23      0
# 24      0
# 25      1
# 26     13

# %%
last_version = pd.read_csv('COVIDStatewiseCount.csv')
last_version.to_csv('COVIDStatewiseCount'+str(date.today())+'.csv')
CoVID_df.to_csv('COVIDStatewiseCount.csv', mode='a', header=False, index=False)

# %%
# out = CoVID_df.to_json(orient='records')
# print(out)
# with open('COVID Statewise Count.json', 'w+') as f:
#     f.write(out)
# Out:
# [{"Name of State \/ UT":"Andhra Pradesh","Total Confirmed cases (Indian National)":8,"Total Confirmed cases ( Foreign National )":0,"Cured\/Discharged\/Migrated":0,"Death":0},{"Name of State \/ UT":"Bihar","Total Confirmed cases (Indian National)":3,"Total Confirmed cases ( Foreign National )":0,"Cured\/Discharged\/Migrated":0,"Death":1},{"Name of State \/ UT":"Chhattisgarh","Total Confirmed cases (Indian National)":1,"Total Confirmed cases ( Foreign National )":0,"Cured\/Discharged\/Migrated":0,"Death":0},{"Name of State \/ UT":"Delhi","Total Confirmed cases (Indian National)":29,"Total Confirmed cases ( Foreign National )":1,"Cured\/Discharged\/Migrated":6,"Death":2},{"Name of State \/ UT":"Gujarat","Total Confirmed cases (Indian National)":32,"Total Confirmed cases ( Foreign National )":1,"Cured\/Discharged\/Migrated":0,"Death":1},{"Name of State \/ UT":"Haryana","Total Confirmed cases (Indian National)":14,"Total Confirmed cases ( Foreign National )":14,"Cured\/Discharged\/Migrated":11,"Death":0},{"Name of State \/ UT":"Himachal Pradesh","Total Confirmed cases (Indian National)":3,"Total Confirmed cases ( Foreign National )":0,"Cured\/Discharged\/Migrated":0,"Death":1},{"Name of State \/ UT":"Karnataka","Total Confirmed cases (Indian National)":37,"Total Confirmed cases ( Foreign National )":0,"Cured\/Discharged\/Migrated":3,"Death":1},{"Name of State \/ UT":"Kerala","Total Confirmed cases (Indian National)":87,"Total Confirmed cases ( Foreign National )":8,"Cured\/Discharged\/Migrated":4,"Death":0},{"Name of State \/ UT":"Madhya Pradesh","Total Confirmed cases (Indian National)":7,"Total Confirmed cases ( Foreign National )":0,"Cured\/Discharged\/Migrated":0,"Death":0},{"Name of State \/ UT":"Maharashtra","Total Confirmed cases (Indian National)":86,"Total Confirmed cases ( Foreign National )":3,"Cured\/Discharged\/Migrated":0,"Death":2},{"Name of State \/ UT":"Manipur","Total Confirmed cases (Indian National)":1,"Total Confirmed cases ( Foreign National )":0,"Cured\/Discharged\/Migrated":0,"Death":0},{"Name of State \/ UT":"Odisha","Total Confirmed cases (Indian National)":2,"Total Confirmed cases ( Foreign National )":0,"Cured\/Discharged\/Migrated":0,"Death":0},{"Name of State \/ UT":"Puducherry","Total Confirmed cases (Indian National)":1,"Total Confirmed cases ( Foreign National )":0,"Cured\/Discharged\/Migrated":0,"Death":0},{"Name of State \/ UT":"Punjab","Total Confirmed cases (Indian National)":29,"Total Confirmed cases ( Foreign National )":0,"Cured\/Discharged\/Migrated":0,"Death":1},{"Name of State \/ UT":"Rajasthan","Total Confirmed cases (Indian National)":30,"Total Confirmed cases ( Foreign National )":2,"Cured\/Discharged\/Migrated":3,"Death":0},{"Name of State \/ UT":"Tamil Nadu","Total Confirmed cases (Indian National)":13,"Total Confirmed cases ( Foreign National )":2,"Cured\/Discharged\/Migrated":1,"Death":0},{"Name of State \/ UT":"Telengana","Total Confirmed cases (Indian National)":25,"Total Confirmed cases ( Foreign National )":10,"Cured\/Discharged\/Migrated":1,"Death":0},{"Name of State \/ UT":"Chandigarh","Total Confirmed cases (Indian National)":7,"Total Confirmed cases ( Foreign National )":0,"Cured\/Discharged\/Migrated":0,"Death":0},{"Name of State \/ UT":"Jammu and Kashmir","Total Confirmed cases (Indian National)":4,"Total Confirmed cases ( Foreign National )":0,"Cured\/Discharged\/Migrated":0,"Death":0},{"Name of State \/ UT":"Ladakh","Total Confirmed cases (Indian National)":13,"Total Confirmed cases ( Foreign National )":0,"Cured\/Discharged\/Migrated":0,"Death":0},{"Name of State \/ UT":"Uttar Pradesh","Total Confirmed cases (Indian National)":32,"Total Confirmed cases ( Foreign National )":1,"Cured\/Discharged\/Migrated":11,"Death":0},{"Name of State \/ UT":"Uttarakhand","Total Confirmed cases (Indian National)":3,"Total Confirmed cases ( Foreign National )":1,"Cured\/Discharged\/Migrated":0,"Death":0},{"Name of State \/ UT":"West Bengal","Total Confirmed cases (Indian National)":9,"T ...
